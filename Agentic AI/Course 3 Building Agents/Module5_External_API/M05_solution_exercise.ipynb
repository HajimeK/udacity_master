# %% [markdown]
# # [SOLUTION] Exercise - Create an Agent with external API call enabled
#
# In this exercise, you'll build an agent that can interact with external APIs to gather real-time data
# and provide responses based on that information. You'll combine concepts from state management and
# memory while adding the ability to make external API calls safely and effectively.

# %% [markdown]
# ## Challenge
#
# Your task is to create an agent that can make External API Calls:
#
# - Implement tools that interact with real APIs
# - Handle API responses and errors gracefully
# - Use environment variables for API keys
# - Process and format API data for user consumption

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
import os
import random
from typing import List
import requests
from dotenv import load_dotenv

from lib.agents import Agent
from lib.messages import BaseMessage
from lib.tooling import tool

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Define API tools

# %% [markdown]
# Feel free to use any open service available through APIs.
#
# Here are a few examples. You can follow the instructions given.
# - https://jsonplaceholder.typicode.com/guide/
# - https://www.exchangerate-api.com/
# - https://openweathermap.org/
#
# Or you can find one you're interested in here.
# - https://github.com/public-apis/public-apis

# %%
@tool
def get_weather(city: str) -> dict:
    """
    Get current weather for a city using OpenWeather API
    args:
        city (str): Name of the city to get weather for
    """
    API_KEY = os.getenv("OPENWEATHER_API_KEY")
    BASE_URL = "https://api.openweathermap.org/data/3.0/weather"

    params = {
        "q": city,
        "appid": API_KEY,
        "units": "metric"
    }

    response = requests.get(BASE_URL, params=params)
    response.raise_for_status()
    return response.json()

# %%
@tool
def get_exchange_rate(from_currency: str = "USD") -> dict:
    """
    Get latest exchange rates from a base currency
    args:
        from_currency (str): Base currency code (default: USD)
    """
    API_KEY = os.getenv("EXCHANGERATE_API_KEY")
    BASE_URL = "https://v6.exchangerate-api.com/v6"

    url = f"{BASE_URL}/{API_KEY}/latest/{from_currency}"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()

# %%
@tool
def get_random_pokemon() -> dict:
    """Get a random Pokemon from the original 151"""
    URL = "https://pokeapi.co/api/v2/pokemon?limit=151"
    response = requests.get(URL)
    response.raise_for_status()
    return random.choice(response.json()['results'])

# %%
tools = [get_weather, get_exchange_rate, get_random_pokemon]

# %%
agent = Agent(
    model_name="gpt-4o-mini",
    instructions=(
        "You are an assistant that can help with:\n"
        "1. Getting weather information for cities\n"
        "2. Checking currency exchange rates\n"
        "3. Getting a random Pokemon\n"
        "Use the available tools to help answer questions about these topics.\n"
        "Maintain context across conversations within the same session."
    ),
    tools=tools
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages:
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run your Agent

# %%
session_id = "external_tools"

# %%
run1 = agent.invoke(
    query="What's the weather like in London?",
    session_id=session_id,
)

print("\nMessages from run 1:")
messages = run1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 run1 = agent.invoke(
#       2     query="What's the weather like in London?",
#       3     session_id=session_id,
#       4 )
#       6 print("\nMessages from run 1:")
#       7 messages = run1.get_final_state()["messages"]
#
# File c:\Users\smeck\git\udacity_master\Agentic AI\Course 3 Building Agents\Module5_External_API\lib\agents.py:167, in Agent.invoke(self, query, session_id)
#     157         previous_messages = last_state["messages"]
#     159 initial_state: AgentState = {
#     160     "user_query": query,
#     161     "instructions": self.instructions,
#    (...)    164     "session_id": session_id,
#     165 }
# --> 167 run_object = self.workflow.run(initial_state)
#     169 # Store the complete run object in memory
#     170 self.memory.add(run_object, session_id)
#
# File c:\Users\smeck\git\udacity_master\Agentic AI\Course 3 Building Agents\Module5_External_API\lib\state_machine.py:206, in StateMachine.run(self, state)
#     203     break
#     205 # Replace state entirely
# --> 206 state = step.run(state, self.state_schema)
#     208 if isinstance(step, EntryPoint):
#     209     print(f"[StateMachine] Starting: {current_step_id}")
#
# File c:\Users\smeck\git\udacity_master\Agentic AI\Course 3 Building Agents\Module5_External_API\lib\state_machine.py:22, in Step.run(self, state, state_schema)
#      21 def run(self, state: StateSchema, state_schema: Type[StateSchema]) -> StateSchema:
# ---> 22     result = self.logic(state)
#      23     # Get expected fields from the TypedDict
#      24     expected_fields = get_type_hints(state_schema)
#
# File c:\Users\smeck\git\udacity_master\Agentic AI\Course 3 Building Agents\Module5_External_API\lib\agents.py:91, in Agent._tool_step(self, state)
#      89 tool = next((t for t in self.tools if t.name == function_name), None)
#      90 if tool:
# ---> 91     result = str(tool(**function_args))
#      92     tool_message = ToolMessage(
#      93         content=json.dumps(result),
#      94         tool_call_id=tool_call_id,
#      95         name=function_name,
#      96     )
#      97     tool_messages.append(tool_message)
#
# File c:\Users\smeck\git\udacity_master\Agentic AI\Course 3 Building Agents\Module5_External_API\lib\tooling.py:106, in Tool.__call__(self, *args, **kwargs)
#     105 def __call__(self, *args, **kwargs):
# --> 106     return self.func(*args, **kwargs)
#
# Cell In[12], line 18, in get_weather(city)
#      11 params = {
#      12     "q": city,
#      13     "appid": API_KEY,
#      14     "units": "metric"
#      15 }
#      17 response = requests.get(BASE_URL, params=params)
# ---> 18 response.raise_for_status()
#      19 return response.json()
#
# File c:\Users\smeck\anaconda3\envs\openai\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/3.0/weather?q=London&appid=y07f848f3733c19badf39bb24c003dcb1&units=metric

# %%
run2 = agent.invoke(
    query="What's the exchange rate from USD to EUR?",
    session_id=session_id,
)
print("\nMessages from run 2:")
messages = run2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1767052801, 'time_last_update_utc': 'Tue, 30 Dec 2025 00:00:01 +0000', 'time_next_update_unix': 1767139201, 'time_next_update_utc': 'Wed, 31 Dec 2025 00:00:01 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 65.7835, 'ALL': 81.9788, 'AMD': 381.4432, 'ANG': 1.79, 'AOA': 919.4366, 'ARS': 1452.25, 'AUD': 1.494, 'AWG': 1.79, 'AZN': 1.701, 'BAM': 1.6618, 'BBD': 2.0, 'BDT': 122.3115, 'BGN': 1.6618, 'BHD': 0.376, 'BIF': 2966.3549, 'BMD': 1.0, 'BND': 1.2856, 'BOB': 6.9282, 'BRL': 5.5718, 'BSD': 1.0, 'BTN': 90.0124, 'BWP': 13.6755, 'BYN': 2.8905, 'BZD': 2.0, 'CAD': 1.3687, 'CDF': 2243.777, 'CHF': 0.7894, 'CLF': 0.02293, 'CLP': 906.388, 'CNH': 7.0031, 'CNY': 7.0166, 'COP': 3694.8263, 'CRC': 495.8162, 'CUP': 24.0, 'CVE': 93.687, 'CZK': 20.6225, 'DJF': 177.721, 'DKK': 6.3412, 'DOP': 62.785, 'DZD': 129.6138, 'EGP': 47.7108, 'ERN': 15.0, 'ETB': 154.6356, 'EUR': 0.8495, 'FJD': 2.2719, 'FKP': 0.7409, 'FOK': 6.3412, 'GBP': 0.7407, 'GEL': 2.6939, 'GGP': 0.7409, 'GHS': 10.9395, 'GIP': 0.7409, 'GMD': 74.1065, 'GNF': 8733.6934, 'GTQ': 7.6675, 'GYD': 209.1809, 'HKD': 7.7742, 'HNL': 26.3859, 'HRK': 6.4017, 'HTG': 130.9794, 'HUF': 328.8601, 'IDR': 16755.1057, 'ILS': 3.1923, 'IMP': 0.7409, 'INR': 90.0097, 'IQD': 1309.8457, 'IRR': 42439.7314, 'ISK': 125.6222, 'JEP': 0.7409, 'JMD': 159.2752, 'JOD': 0.709, 'JPY': 156.1419, 'KES': 128.925, 'KGS': 87.3913, 'KHR': 4015.5982, 'KID': 1.494, 'KMF': 418.0018, 'KRW': 1434.6892, 'KWD': 0.3074, 'KYD': 0.8333, 'KZT': 501.7448, 'LAK': 21699.3359, 'LBP': 89500.0, 'LKR': 309.6135, 'LRD': 177.7292, 'LSL': 16.6878, 'LYD': 5.412, 'MAD': 9.11, 'MDL': 16.759, 'MGA': 4565.7647, 'MKD': 52.1859, 'MMK': 2103.3638, 'MNT': 3580.4094, 'MOP': 8.0076, 'MRU': 39.7619, 'MUR': 46.051, 'MVR': 15.451, 'MWK': 1743.6204, 'MXN': 17.962, 'MYR': 4.0583, 'MZN': 63.6386, 'NAD': 16.6878, 'NGN': 1448.8346, 'NIO': 36.8387, 'NOK': 10.046, 'NPR': 144.0198, 'NZD': 1.7227, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3676, 'PGK': 4.3226, 'PHP': 58.8479, 'PKR': 280.381, 'PLN': 3.5913, 'PYG': 6792.5068, 'QAR': 3.64, 'RON': 4.3249, 'RSD': 99.7591, 'RUB': 77.6626, 'RWF': 1457.9681, 'SAR': 3.75, 'SBD': 8.1175, 'SCR': 14.2465, 'SDG': 449.2658, 'SEK': 9.1844, 'SGD': 1.2853, 'SHP': 0.7409, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.4578, 'SRD': 38.4248, 'SSP': 4720.4431, 'STN': 20.8165, 'SYP': 11011.9031, 'SZL': 16.6878, 'THB': 31.5209, 'TJS': 9.2309, 'TMT': 3.5, 'TND': 2.8883, 'TOP': 2.3888, 'TRY': 42.9462, 'TTD': 6.7797, 'TVD': 1.494, 'TWD': 31.3826, 'TZS': 2443.7035, 'UAH': 42.2277, 'UGX': 3582.6798, 'UYU': 39.301, 'UZS': 12083.844, 'VES': 298.1431, 'VND': 26174.6331, 'VUV': 120.8271, 'WST': 2.7386, 'XAF': 557.3357, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.725, 'XOF': 557.3357, 'XPF': 101.3908, 'YER': 238.5511, 'ZAR': 16.685, 'ZMW': 22.4403, 'ZWG': 26.0108, 'ZWL': 26.0108}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8495 EUR** for 1 USD., tool_calls = None)

# %%
run3 = agent.invoke(
    query="Pick one random Pokemon!",
    session_id=session_id,
)
print("\nMessages from run 3:")
messages = run3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1767052801, 'time_last_update_utc': 'Tue, 30 Dec 2025 00:00:01 +0000', 'time_next_update_unix': 1767139201, 'time_next_update_utc': 'Wed, 31 Dec 2025 00:00:01 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 65.7835, 'ALL': 81.9788, 'AMD': 381.4432, 'ANG': 1.79, 'AOA': 919.4366, 'ARS': 1452.25, 'AUD': 1.494, 'AWG': 1.79, 'AZN': 1.701, 'BAM': 1.6618, 'BBD': 2.0, 'BDT': 122.3115, 'BGN': 1.6618, 'BHD': 0.376, 'BIF': 2966.3549, 'BMD': 1.0, 'BND': 1.2856, 'BOB': 6.9282, 'BRL': 5.5718, 'BSD': 1.0, 'BTN': 90.0124, 'BWP': 13.6755, 'BYN': 2.8905, 'BZD': 2.0, 'CAD': 1.3687, 'CDF': 2243.777, 'CHF': 0.7894, 'CLF': 0.02293, 'CLP': 906.388, 'CNH': 7.0031, 'CNY': 7.0166, 'COP': 3694.8263, 'CRC': 495.8162, 'CUP': 24.0, 'CVE': 93.687, 'CZK': 20.6225, 'DJF': 177.721, 'DKK': 6.3412, 'DOP': 62.785, 'DZD': 129.6138, 'EGP': 47.7108, 'ERN': 15.0, 'ETB': 154.6356, 'EUR': 0.8495, 'FJD': 2.2719, 'FKP': 0.7409, 'FOK': 6.3412, 'GBP': 0.7407, 'GEL': 2.6939, 'GGP': 0.7409, 'GHS': 10.9395, 'GIP': 0.7409, 'GMD': 74.1065, 'GNF': 8733.6934, 'GTQ': 7.6675, 'GYD': 209.1809, 'HKD': 7.7742, 'HNL': 26.3859, 'HRK': 6.4017, 'HTG': 130.9794, 'HUF': 328.8601, 'IDR': 16755.1057, 'ILS': 3.1923, 'IMP': 0.7409, 'INR': 90.0097, 'IQD': 1309.8457, 'IRR': 42439.7314, 'ISK': 125.6222, 'JEP': 0.7409, 'JMD': 159.2752, 'JOD': 0.709, 'JPY': 156.1419, 'KES': 128.925, 'KGS': 87.3913, 'KHR': 4015.5982, 'KID': 1.494, 'KMF': 418.0018, 'KRW': 1434.6892, 'KWD': 0.3074, 'KYD': 0.8333, 'KZT': 501.7448, 'LAK': 21699.3359, 'LBP': 89500.0, 'LKR': 309.6135, 'LRD': 177.7292, 'LSL': 16.6878, 'LYD': 5.412, 'MAD': 9.11, 'MDL': 16.759, 'MGA': 4565.7647, 'MKD': 52.1859, 'MMK': 2103.3638, 'MNT': 3580.4094, 'MOP': 8.0076, 'MRU': 39.7619, 'MUR': 46.051, 'MVR': 15.451, 'MWK': 1743.6204, 'MXN': 17.962, 'MYR': 4.0583, 'MZN': 63.6386, 'NAD': 16.6878, 'NGN': 1448.8346, 'NIO': 36.8387, 'NOK': 10.046, 'NPR': 144.0198, 'NZD': 1.7227, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3676, 'PGK': 4.3226, 'PHP': 58.8479, 'PKR': 280.381, 'PLN': 3.5913, 'PYG': 6792.5068, 'QAR': 3.64, 'RON': 4.3249, 'RSD': 99.7591, 'RUB': 77.6626, 'RWF': 1457.9681, 'SAR': 3.75, 'SBD': 8.1175, 'SCR': 14.2465, 'SDG': 449.2658, 'SEK': 9.1844, 'SGD': 1.2853, 'SHP': 0.7409, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.4578, 'SRD': 38.4248, 'SSP': 4720.4431, 'STN': 20.8165, 'SYP': 11011.9031, 'SZL': 16.6878, 'THB': 31.5209, 'TJS': 9.2309, 'TMT': 3.5, 'TND': 2.8883, 'TOP': 2.3888, 'TRY': 42.9462, 'TTD': 6.7797, 'TVD': 1.494, 'TWD': 31.3826, 'TZS': 2443.7035, 'UAH': 42.2277, 'UGX': 3582.6798, 'UYU': 39.301, 'UZS': 12083.844, 'VES': 298.1431, 'VND': 26174.6331, 'VUV': 120.8271, 'WST': 2.7386, 'XAF': 557.3357, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.725, 'XOF': 557.3357, 'XPF': 101.3908, 'YER': 238.5511, 'ZAR': 16.685, 'ZMW': 22.4403, 'ZWG': 26.0108, 'ZWL': 26.0108}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8495 EUR** for 1 USD., tool_calls = None)
#  -> (role = user, content = Pick one random Pokemon!, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_hRkH4DZ1r612W9DfBpRyAtJF', function=Function(arguments='{}', name='get_random_pokemon'), type='function')])
#  -> (role = tool, content = "{'name': 'electrode', 'url': 'https://pokeapi.co/api/v2/pokemon/101/'}", tool_calls = None)
#  -> (role = assistant, content = You got a random Pokémon: **Electrode**!
#
# You can find more about it [here](https://pokeapi.co/api/v2/pokemon/101/)., tool_calls = None)

# %% [markdown]
# ## Check session histories

# %%
runs = agent.get_session_runs(session_id)
for i, run_object in enumerate(runs, 1):
    print(f"\n# Run {i}", run_object.metadata)
    print("Messages:")
    print_messages(run_object.get_final_state()["messages"])
# Out:
# # Run 1 {'run_id': '76bc50d0-94a3-408f-a36f-e3004a52a56e', 'start_timestamp': '2025-12-30 20:49:46.104262', 'end_timestamp': '2025-12-30 20:49:48.954156', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1767052801, 'time_last_update_utc': 'Tue, 30 Dec 2025 00:00:01 +0000', 'time_next_update_unix': 1767139201, 'time_next_update_utc': 'Wed, 31 Dec 2025 00:00:01 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 65.7835, 'ALL': 81.9788, 'AMD': 381.4432, 'ANG': 1.79, 'AOA': 919.4366, 'ARS': 1452.25, 'AUD': 1.494, 'AWG': 1.79, 'AZN': 1.701, 'BAM': 1.6618, 'BBD': 2.0, 'BDT': 122.3115, 'BGN': 1.6618, 'BHD': 0.376, 'BIF': 2966.3549, 'BMD': 1.0, 'BND': 1.2856, 'BOB': 6.9282, 'BRL': 5.5718, 'BSD': 1.0, 'BTN': 90.0124, 'BWP': 13.6755, 'BYN': 2.8905, 'BZD': 2.0, 'CAD': 1.3687, 'CDF': 2243.777, 'CHF': 0.7894, 'CLF': 0.02293, 'CLP': 906.388, 'CNH': 7.0031, 'CNY': 7.0166, 'COP': 3694.8263, 'CRC': 495.8162, 'CUP': 24.0, 'CVE': 93.687, 'CZK': 20.6225, 'DJF': 177.721, 'DKK': 6.3412, 'DOP': 62.785, 'DZD': 129.6138, 'EGP': 47.7108, 'ERN': 15.0, 'ETB': 154.6356, 'EUR': 0.8495, 'FJD': 2.2719, 'FKP': 0.7409, 'FOK': 6.3412, 'GBP': 0.7407, 'GEL': 2.6939, 'GGP': 0.7409, 'GHS': 10.9395, 'GIP': 0.7409, 'GMD': 74.1065, 'GNF': 8733.6934, 'GTQ': 7.6675, 'GYD': 209.1809, 'HKD': 7.7742, 'HNL': 26.3859, 'HRK': 6.4017, 'HTG': 130.9794, 'HUF': 328.8601, 'IDR': 16755.1057, 'ILS': 3.1923, 'IMP': 0.7409, 'INR': 90.0097, 'IQD': 1309.8457, 'IRR': 42439.7314, 'ISK': 125.6222, 'JEP': 0.7409, 'JMD': 159.2752, 'JOD': 0.709, 'JPY': 156.1419, 'KES': 128.925, 'KGS': 87.3913, 'KHR': 4015.5982, 'KID': 1.494, 'KMF': 418.0018, 'KRW': 1434.6892, 'KWD': 0.3074, 'KYD': 0.8333, 'KZT': 501.7448, 'LAK': 21699.3359, 'LBP': 89500.0, 'LKR': 309.6135, 'LRD': 177.7292, 'LSL': 16.6878, 'LYD': 5.412, 'MAD': 9.11, 'MDL': 16.759, 'MGA': 4565.7647, 'MKD': 52.1859, 'MMK': 2103.3638, 'MNT': 3580.4094, 'MOP': 8.0076, 'MRU': 39.7619, 'MUR': 46.051, 'MVR': 15.451, 'MWK': 1743.6204, 'MXN': 17.962, 'MYR': 4.0583, 'MZN': 63.6386, 'NAD': 16.6878, 'NGN': 1448.8346, 'NIO': 36.8387, 'NOK': 10.046, 'NPR': 144.0198, 'NZD': 1.7227, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3676, 'PGK': 4.3226, 'PHP': 58.8479, 'PKR': 280.381, 'PLN': 3.5913, 'PYG': 6792.5068, 'QAR': 3.64, 'RON': 4.3249, 'RSD': 99.7591, 'RUB': 77.6626, 'RWF': 1457.9681, 'SAR': 3.75, 'SBD': 8.1175, 'SCR': 14.2465, 'SDG': 449.2658, 'SEK': 9.1844, 'SGD': 1.2853, 'SHP': 0.7409, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.4578, 'SRD': 38.4248, 'SSP': 4720.4431, 'STN': 20.8165, 'SYP': 11011.9031, 'SZL': 16.6878, 'THB': 31.5209, 'TJS': 9.2309, 'TMT': 3.5, 'TND': 2.8883, 'TOP': 2.3888, 'TRY': 42.9462, 'TTD': 6.7797, 'TVD': 1.494, 'TWD': 31.3826, 'TZS': 2443.7035, 'UAH': 42.2277, 'UGX': 3582.6798, 'UYU': 39.301, 'UZS': 12083.844, 'VES': 298.1431, 'VND': 26174.6331, 'VUV': 120.8271, 'WST': 2.7386, 'XAF': 557.3357, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.725, 'XOF': 557.3357, 'XPF': 101.3908, 'YER': 238.5511, 'ZAR': 16.685, 'ZMW': 22.4403, 'ZWG': 26.0108, 'ZWL': 26.0108}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8495 EUR** for 1 USD., tool_calls = None)
#
# # Run 2 {'run_id': 'aa26e931-1a33-48f5-926e-2edef9a9cc1b', 'start_timestamp': '2025-12-30 20:50:07.168026', 'end_timestamp': '2025-12-30 20:50:09.235961', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1767052801, 'time_last_update_utc': 'Tue, 30 Dec 2025 00:00:01 +0000', 'time_next_update_unix': 1767139201, 'time_next_update_utc': 'Wed, 31 Dec 2025 00:00:01 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 65.7835, 'ALL': 81.9788, 'AMD': 381.4432, 'ANG': 1.79, 'AOA': 919.4366, 'ARS': 1452.25, 'AUD': 1.494, 'AWG': 1.79, 'AZN': 1.701, 'BAM': 1.6618, 'BBD': 2.0, 'BDT': 122.3115, 'BGN': 1.6618, 'BHD': 0.376, 'BIF': 2966.3549, 'BMD': 1.0, 'BND': 1.2856, 'BOB': 6.9282, 'BRL': 5.5718, 'BSD': 1.0, 'BTN': 90.0124, 'BWP': 13.6755, 'BYN': 2.8905, 'BZD': 2.0, 'CAD': 1.3687, 'CDF': 2243.777, 'CHF': 0.7894, 'CLF': 0.02293, 'CLP': 906.388, 'CNH': 7.0031, 'CNY': 7.0166, 'COP': 3694.8263, 'CRC': 495.8162, 'CUP': 24.0, 'CVE': 93.687, 'CZK': 20.6225, 'DJF': 177.721, 'DKK': 6.3412, 'DOP': 62.785, 'DZD': 129.6138, 'EGP': 47.7108, 'ERN': 15.0, 'ETB': 154.6356, 'EUR': 0.8495, 'FJD': 2.2719, 'FKP': 0.7409, 'FOK': 6.3412, 'GBP': 0.7407, 'GEL': 2.6939, 'GGP': 0.7409, 'GHS': 10.9395, 'GIP': 0.7409, 'GMD': 74.1065, 'GNF': 8733.6934, 'GTQ': 7.6675, 'GYD': 209.1809, 'HKD': 7.7742, 'HNL': 26.3859, 'HRK': 6.4017, 'HTG': 130.9794, 'HUF': 328.8601, 'IDR': 16755.1057, 'ILS': 3.1923, 'IMP': 0.7409, 'INR': 90.0097, 'IQD': 1309.8457, 'IRR': 42439.7314, 'ISK': 125.6222, 'JEP': 0.7409, 'JMD': 159.2752, 'JOD': 0.709, 'JPY': 156.1419, 'KES': 128.925, 'KGS': 87.3913, 'KHR': 4015.5982, 'KID': 1.494, 'KMF': 418.0018, 'KRW': 1434.6892, 'KWD': 0.3074, 'KYD': 0.8333, 'KZT': 501.7448, 'LAK': 21699.3359, 'LBP': 89500.0, 'LKR': 309.6135, 'LRD': 177.7292, 'LSL': 16.6878, 'LYD': 5.412, 'MAD': 9.11, 'MDL': 16.759, 'MGA': 4565.7647, 'MKD': 52.1859, 'MMK': 2103.3638, 'MNT': 3580.4094, 'MOP': 8.0076, 'MRU': 39.7619, 'MUR': 46.051, 'MVR': 15.451, 'MWK': 1743.6204, 'MXN': 17.962, 'MYR': 4.0583, 'MZN': 63.6386, 'NAD': 16.6878, 'NGN': 1448.8346, 'NIO': 36.8387, 'NOK': 10.046, 'NPR': 144.0198, 'NZD': 1.7227, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3676, 'PGK': 4.3226, 'PHP': 58.8479, 'PKR': 280.381, 'PLN': 3.5913, 'PYG': 6792.5068, 'QAR': 3.64, 'RON': 4.3249, 'RSD': 99.7591, 'RUB': 77.6626, 'RWF': 1457.9681, 'SAR': 3.75, 'SBD': 8.1175, 'SCR': 14.2465, 'SDG': 449.2658, 'SEK': 9.1844, 'SGD': 1.2853, 'SHP': 0.7409, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.4578, 'SRD': 38.4248, 'SSP': 4720.4431, 'STN': 20.8165, 'SYP': 11011.9031, 'SZL': 16.6878, 'THB': 31.5209, 'TJS': 9.2309, 'TMT': 3.5, 'TND': 2.8883, 'TOP': 2.3888, 'TRY': 42.9462, 'TTD': 6.7797, 'TVD': 1.494, 'TWD': 31.3826, 'TZS': 2443.7035, 'UAH': 42.2277, 'UGX': 3582.6798, 'UYU': 39.301, 'UZS': 12083.844, 'VES': 298.1431, 'VND': 26174.6331, 'VUV': 120.8271, 'WST': 2.7386, 'XAF': 557.3357, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.725, 'XOF': 557.3357, 'XPF': 101.3908, 'YER': 238.5511, 'ZAR': 16.685, 'ZMW': 22.4403, 'ZWG': 26.0108, 'ZWL': 26.0108}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8495 EUR** for 1 USD., tool_calls = None)
#  -> (role = user, content = Pick one random Pokemon!, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_hRkH4DZ1r612W9DfBpRyAtJF', function=Function(arguments='{}', name='get_random_pokemon'), type='function')])
#  -> (role = tool, content = "{'name': 'electrode', 'url': 'https://pokeapi.co/api/v2/pokemon/101/'}", tool_calls = None)
#  -> (role = assistant, content = You got a random Pokémon: **Electrode**!
#
# You can find more about it [here](https://pokeapi.co/api/v2/pokemon/101/)., tool_calls = None)

# %%
runs = agent.get_session_runs(session_id)
for run_object in runs:
    print(run_object)
    for snp in run_object.snapshots:
        print(f"-> {snp}")
    print("\n")
# Out:
# Run('76bc50d0-94a3-408f-a36f-e3004a52a56e')
# -> Snapshot('c646c0e2-c0bb-477b-8117-4992c051b808') @ [2025-12-30 20:49:46.104369]: __entry__.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('9f0f70ec-acab-4c65-8db3-f83d94856cb5') @ [2025-12-30 20:49:46.104460]: message_prep.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?")], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('d28ad4ff-27d3-4412-b906-cfd5bda42968') @ [2025-12-30 20:49:47.122184]: llm_processor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])], 'current_tool_calls': [ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')], 'session_id': 'external_tools'})
# -> Snapshot('d82693b9-4ff5-40ef-938d-5bd426e13adf') @ [2025-12-30 20:49:47.753780]: tool_executor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\':  ...
# -> Snapshot('121e6dff-a49c-45d6-9336-76067a5d2de4') @ [2025-12-30 20:49:48.954129]: llm_processor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\':  ...
#
#
# Run('aa26e931-1a33-48f5-926e-2edef9a9cc1b')
# -> Snapshot('0169aefb-3faa-40b3-918c-c099a2cff7e6') @ [2025-12-30 20:50:07.168182]: __entry__.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\': 9.2309, \'TMT\': 3.5, ...
# -> Snapshot('70436217-8887-4054-a0e1-05f3fb31104b') @ [2025-12-30 20:50:07.168295]: message_prep.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\': 9.2309, \'TMT\': 3 ...
# -> Snapshot('57cc2405-7b5d-47e0-8b8b-0a2f2c54699b') @ [2025-12-30 20:50:07.850584]: llm_processor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\': 9.2309, \'TMT\':  ...
# -> Snapshot('a9c2c5ca-3607-4935-87ce-b771eb4999d9') @ [2025-12-30 20:50:08.256253]: tool_executor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\': 9.2309, \'TMT\':  ...
# -> Snapshot('c5c649d4-82c8-4305-b923-da5d20e3bcc1') @ [2025-12-30 20:50:09.235938]: llm_processor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_gBHwn1SldgKoltFMGMtvdvEz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-api.com/docs\', \'terms_of_use\': \'https://www.exchangerate-api.com/terms\', \'time_last_update_unix\': 1767052801, \'time_last_update_utc\': \'Tue, 30 Dec 2025 00:00:01 +0000\', \'time_next_update_unix\': 1767139201, \'time_next_update_utc\': \'Wed, 31 Dec 2025 00:00:01 +0000\', \'base_code\': \'USD\', \'conversion_rates\': {\'USD\': 1, \'AED\': 3.6725, \'AFN\': 65.7835, \'ALL\': 81.9788, \'AMD\': 381.4432, \'ANG\': 1.79, \'AOA\': 919.4366, \'ARS\': 1452.25, \'AUD\': 1.494, \'AWG\': 1.79, \'AZN\': 1.701, \'BAM\': 1.6618, \'BBD\': 2.0, \'BDT\': 122.3115, \'BGN\': 1.6618, \'BHD\': 0.376, \'BIF\': 2966.3549, \'BMD\': 1.0, \'BND\': 1.2856, \'BOB\': 6.9282, \'BRL\': 5.5718, \'BSD\': 1.0, \'BTN\': 90.0124, \'BWP\': 13.6755, \'BYN\': 2.8905, \'BZD\': 2.0, \'CAD\': 1.3687, \'CDF\': 2243.777, \'CHF\': 0.7894, \'CLF\': 0.02293, \'CLP\': 906.388, \'CNH\': 7.0031, \'CNY\': 7.0166, \'COP\': 3694.8263, \'CRC\': 495.8162, \'CUP\': 24.0, \'CVE\': 93.687, \'CZK\': 20.6225, \'DJF\': 177.721, \'DKK\': 6.3412, \'DOP\': 62.785, \'DZD\': 129.6138, \'EGP\': 47.7108, \'ERN\': 15.0, \'ETB\': 154.6356, \'EUR\': 0.8495, \'FJD\': 2.2719, \'FKP\': 0.7409, \'FOK\': 6.3412, \'GBP\': 0.7407, \'GEL\': 2.6939, \'GGP\': 0.7409, \'GHS\': 10.9395, \'GIP\': 0.7409, \'GMD\': 74.1065, \'GNF\': 8733.6934, \'GTQ\': 7.6675, \'GYD\': 209.1809, \'HKD\': 7.7742, \'HNL\': 26.3859, \'HRK\': 6.4017, \'HTG\': 130.9794, \'HUF\': 328.8601, \'IDR\': 16755.1057, \'ILS\': 3.1923, \'IMP\': 0.7409, \'INR\': 90.0097, \'IQD\': 1309.8457, \'IRR\': 42439.7314, \'ISK\': 125.6222, \'JEP\': 0.7409, \'JMD\': 159.2752, \'JOD\': 0.709, \'JPY\': 156.1419, \'KES\': 128.925, \'KGS\': 87.3913, \'KHR\': 4015.5982, \'KID\': 1.494, \'KMF\': 418.0018, \'KRW\': 1434.6892, \'KWD\': 0.3074, \'KYD\': 0.8333, \'KZT\': 501.7448, \'LAK\': 21699.3359, \'LBP\': 89500.0, \'LKR\': 309.6135, \'LRD\': 177.7292, \'LSL\': 16.6878, \'LYD\': 5.412, \'MAD\': 9.11, \'MDL\': 16.759, \'MGA\': 4565.7647, \'MKD\': 52.1859, \'MMK\': 2103.3638, \'MNT\': 3580.4094, \'MOP\': 8.0076, \'MRU\': 39.7619, \'MUR\': 46.051, \'MVR\': 15.451, \'MWK\': 1743.6204, \'MXN\': 17.962, \'MYR\': 4.0583, \'MZN\': 63.6386, \'NAD\': 16.6878, \'NGN\': 1448.8346, \'NIO\': 36.8387, \'NOK\': 10.046, \'NPR\': 144.0198, \'NZD\': 1.7227, \'OMR\': 0.3845, \'PAB\': 1.0, \'PEN\': 3.3676, \'PGK\': 4.3226, \'PHP\': 58.8479, \'PKR\': 280.381, \'PLN\': 3.5913, \'PYG\': 6792.5068, \'QAR\': 3.64, \'RON\': 4.3249, \'RSD\': 99.7591, \'RUB\': 77.6626, \'RWF\': 1457.9681, \'SAR\': 3.75, \'SBD\': 8.1175, \'SCR\': 14.2465, \'SDG\': 449.2658, \'SEK\': 9.1844, \'SGD\': 1.2853, \'SHP\': 0.7409, \'SLE\': 24.1139, \'SLL\': 24113.8848, \'SOS\': 570.4578, \'SRD\': 38.4248, \'SSP\': 4720.4431, \'STN\': 20.8165, \'SYP\': 11011.9031, \'SZL\': 16.6878, \'THB\': 31.5209, \'TJS\': 9.2309, \'TMT\':  ...
