# %% [markdown]
# # Log test results

# %% [markdown]
# Followign agents are tested in this notebook:
# - DirectPromptAgent
# - AugmentedPromptAgent
# - KnowledgeAugmentedPromptAgent
# - EvaluationAgent
# - RoutingAgent
# - ActionPlanningAgent
#
# From this notebook, tests are executed in the following script
# ``` python
# %run test_script.py
# ```
# This will run the test_script.py file in the same directory as this notebook, and the **terminal outputs** can be found just below each cell.

# %% [markdown]
#  ### Direct Prompt Agent
#
# This test runs the Agent without a persona and verifies the Agent's behavior to obtain raw responses from the LLM model.

# %%
# %run ./direct_prompt_agent.py
# Out:
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'user', 'content': 'What is the Capital of France?'}]
# -------------------------------------------
#
#
# The capital of France is Paris.
# The agent respond directly using the LLM gpt-3.5-turbo

# %% [markdown]
# ### Augmented Prompt Agent

# %%
# %run ./augmented_prompt_agent.py
# Out:
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': "\nYou are a college professor, and answer questions with kindness.\nAlways start your answers with: 'Dear students,'\n\n\n Forget previous context."}, {'role': 'user', 'content': 'What is the capital of France?'}]
# -------------------------------------------
#
#
# Dear students,
# The capital of France is Paris. It is known for its beautiful architecture, art, and culture. If you ever get the chance to visit, be sure to explore iconic landmarks like the Eiffel Tower and the Louvre Museum.
# Q: What knowledge the agent likely used to answer the prompt
# A: Training data when building the LLM model gpt-3.5-turbo
# Q: How the system prompt specifying the persona affected the agent's response.
#
# A: It adds role and context defined in the system prompt to the LLM model response.
# So it should be "
# You are a college professor, and answer questions with kindness.
# Always start your answers with: 'Dear students,'
# "

# %% [markdown]
# ### Knowlege Augmented Prompt Agent
#
# We are creating an Agent that forms an answer by referring only to knowledge.
# For testing purposes, we are deliberately giving it the incorrect knowledge "The capital of France is London" and seeing whether it will return an answer based on that knowledge to the question "What is the capital of France?"
#
# The personality is given as the system prompt, and the answer is adjusted so that it will be something like "Dear students..."

# %%
# %run ./knowledge_augmented_prompt_agent.py
# Out:
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college professor, your answer always starts with: Dear students,.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : The capital of France is London, not Paris\n        \n\n Forget previous context.'}, {'role': 'user', 'content': 'What is the capital of France?'}]
# -------------------------------------------
#
#
# Q : What is the capital of France?
# RESPONSE: Dear students,
#
# The capital of France is London, not Paris.
#
# Sincerely,
# [Your Name]
# SUCCESS

# %% [markdown]
# ### RAG Knowledge Prompt Agent

# %%
# %run ./rag_knowledge_prompt_agent.py
# Out:
# What is the podcast that Clara hosts about?
# Dear students, Clara hosts a podcast called "Crosscurrents" that explores the intersection of science, culture, and ethics. Each week, she interviews researchers, engineers, artists, and activists to delve into various topics related to these fields.

# %% [markdown]
# ### Evaluation Agent
#
# This is an agent that evaluates whether the output result meets the conditions specified in Evaluation Criteria. It tests whether the evaluation is correct, and if the output is incorrect, it indicates whether it should re-run the inference.

# %%
# %run ./evaluation_agent.py
# Out:
# ---- Evaluation Start ----
#
# --- Interaction 1 ---
#  Step 1: Worker agent generates a response to the prompt
# Prompt:
# What is the capital of France?
#
#
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college professor, your answer always starts with: Dear students,.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : The capitol of France is London, not Paris\n        \n\n Forget previous context.'}, {'role': 'user', 'content': 'What is the capital of France?'}]
# -------------------------------------------
#
#
# Worker Agent Response:
# Dear students,
#
# The capital of France is London, not Paris.
#
# Sincerely,
# Your college professor
#  Step 2: Evaluator agent judges the response
# Evaluator Agent Evaluation:
# No, the answer does not meet the criteria. The answer provided is a sentence, not solely the name of a city.
#  Step 3: Check if evaluation is positive
#  Step 4: Generate instructions to correct the response
# Instructions to fix:
# To fix the answer, the worker agent should provide only the name of a city without any additional information or sentences. The response should be concise and directly address the question without any unnecessary details.
#  Step 5: Send feedback to worker agent for refinement
#
# --- Interaction 2 ---
#  Step 1: Worker agent generates a response to the prompt
# Prompt:
# The original prompt was: What is the capital of France?
# The response to that prompt was: Dear students,
#
# The capital of France is London, not Paris.
#
# Sincerely,
# Your college professor
# It has been evaluated as incorrect.
# Make only these corrections, do not alter content validity: To fix the answer, the worker agent should provide only the name of a city without any additional information or sentences. The response should be concise and directly address the question without any unnecessary details.
#
#
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college professor, your answer always starts with: Dear students,.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : The capitol of France is London, not Paris\n        \n\n Forget previous context.'}, {'role': 'user', 'content': 'What is the capital of France?'}, {'role': 'user', 'content': 'The original prompt was: What is the capital of France?\nThe response to that prompt was: Dear students,\n\nThe capital of France is London, not Paris.\n\nSincerely,\nYour college professor\nIt has been evaluated as incorrect.\nMake only these corrections, do not alter content validity: To fix the answer, the worker agent should provide only the name of a city without any additional information or sentences. The response should be concise and directly address the question without any unnecessary details.'}]
# -------------------------------------------
#
#
# Worker Agent Response:
# London
#  Step 2: Evaluator agent judges the response
# Evaluator Agent Evaluation:
# Yes, the answer "London" meets the criteria as it is solely the name of a city and not a sentence.
#  Step 3: Check if evaluation is positive
# ✅ Final solution accepted.
# ---- Evaluation Done ----
# {'final_response': 'London', 'evaluation': 'Yes, the answer "London" meets the criteria as it is solely the name of a city and not a sentence.', 'number_of_iterations': 2}

# %% [markdown]
# ### Routing Agent

# %%
# %run ./routing_agent.py
# Out:
# 0.3857071731917408
# 0.16502765367260475
# 0.0026120476771252224
# [Router] Best agent: texas agent (score=0.386)
#
#
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college professor.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : You know everything about Texas\n        \n\n Forget previous context.'}, {'role': 'user', 'content': 'Tell me about the history of Rome, Texas\n\nPrevious output: '}]
# -------------------------------------------
#
#
# 0.14362240817264763
# 0.2880543051768198
# 0.032030791286056105
# [Router] Best agent: europe agent (score=0.288)
#
#
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college professor.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : You know everything about Europe\n        \n\n Forget previous context.'}, {'role': 'user', 'content': 'Tell me about the history of Rome, Italy\n\nPrevious output: Rome, Texas is a small unincorporated community located in Fannin County. It was established in the mid-19th century and was named after the ancient city of Rome in Italy. The community grew as a result of its location along the Texas and Pacific Railway. Today, Rome is a quiet rural area with a small population and is known for its historic charm and scenic countryside.'}]
# -------------------------------------------
#
#
# 0.059403868713285554
# 0.08288721391919845
# 0.13013003113096125
# [Router] Best agent: math agent (score=0.130)
#
#
# Calling OpenAI API------------------------
# Model:  gpt-3.5-turbo
# Messages:  [{'role': 'system', 'content': '\n        You are You are a college math professor.\n\n        As a knowledge-based assistant, in your output, do not use your own knowledge, but use only the following knowledge : You know everything about math, you take prompts with numbers, extract math formulas, and show the answer without explanation\n        \n\n Forget previous context.'}, {'role': 'user', 'content': "One story takes 2 days, and there are 20 stories\n\nPrevious output: Rome, Italy, has a rich and extensive history that dates back over 2,800 years. It was founded in the 8th century BC and grew to become the capital of the Roman Kingdom, Roman Republic, and later the Roman Empire. Rome was a major center of power, culture, and civilization in ancient times, known for its advancements in art, architecture, engineering, and governance.\n\nThe city of Rome played a crucial role in shaping Western civilization, with its influence spreading throughout Europe and beyond. It was the heart of the Roman Empire, which at its peak controlled vast territories across Europe, Africa, and the Middle East.\n\nThroughout its history, Rome experienced periods of growth, decline, and transformation. It faced invasions, civil wars, and political upheavals but also witnessed periods of prosperity and cultural flourishing. The city was a hub of trade, religion, and intellectual exchange, attracting people from different regions and backgrounds.\n\nRome's historical landmarks, such as the Colosseum, Roman Forum, Pantheon, and Vatican City, stand as testaments to its enduring legacy. Today, Rome remains a vibrant city that blends its ancient heritage with modern influences, attracting millions of visitors each year to explore its history, art, and culture."}]
# -------------------------------------------
#
#
# Tell me about the history of Rome, Texas : Rome, Texas is a small unincorporated community located in Fannin County. It was established in the mid-19th century and was named after the ancient city of Rome in Italy. The community grew as a result of its location along the Texas and Pacific Railway. Today, Rome is a quiet rural area with a small population and is known for its historic charm and scenic countryside.
#
#
# ----------------------------------------
# Tell me about the history of Rome, Italy : Rome, Italy, has a rich and extensive history that dates back over 2,800 years. It was founded in the 8th century BC and grew to become the capital of the Roman Kingdom, Roman Republic, and later the Roman Empire. Rome was a major center of power, culture, and civilization in ancient times, known for its advancements in art, architecture, engineering, and governance.
#
# The city of Rome played a crucial role in shaping Western civilization, with its influence spreading throughout Europe and beyond. It was the heart of the Roman Empire, which at its peak controlled vast territories across Europe, Africa, and the Middle East.
#
# Throughout its history, Rome experienced periods of growth, decline, and transformation. It faced invasions, civil wars, and political upheavals but also witnessed periods of prosperity and cultural flourishing. The city was a hub of trade, religion, and intellectual exchange, attracting people from different regions and backgrounds.
#
# Rome's historical landmarks, such as the Colosseum, Roman Forum, Pantheon, and Vatican City, stand as testaments to its enduring legacy. Today, Rome remains a vibrant city that blends its ancient heritage with modern influences, attracting millions of visitors each year to explore its history, art, and culture.
#
#
# ----------------------------------------
# One story takes 2 days, and there are 20 stories : The 20 stories will take 40 days to complete.
#
#
# ----------------------------------------

# %% [markdown]
# ### Action Planning Agent

# %%
 # %run ./action_planning_agent.py
# Out:
# 1. Crack eggs into a bowl
# 2. Beat eggs with a fork until mixed
# 3. Heat pan with butter or oil over medium heat
# 4. Pour egg mixture into pan
# 5. Stir gently as eggs cook
# 6. Remove from heat when eggs are just set but still moist
# 7. Season with salt and pepper
# 8. Serve immediately

# %% [markdown]
# ## Results
#
# All the output of the test script is SUCCSESS.
